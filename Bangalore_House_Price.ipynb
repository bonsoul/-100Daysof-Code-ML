# %% [markdown]
# <a href="https://colab.research.google.com/github/bonsoul/-100Daysof-Code-ML/blob/main/Bangalore_House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("amitabhajoy/bengaluru-house-price-data")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/amitabhajoy/bengaluru-house-price-data?dataset_version_number=2...
# 100%|██████████| 195k/195k [00:00<00:00, 41.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/amitabhajoy/bengaluru-house-price-data/versions/2

# %%
# List files in the downloaded directory to identify the file name
for file in os.listdir(path):
    print(file)

# Assuming the file name is 'Bengaluru_House_Data.csv' based on common naming conventions
try:
    file_name = 'Bengaluru_House_Data.csv'  # Replace with actual filename if different
    file_path = os.path.join(path, file_name)
    df = pd.read_csv(file_path)

    # Display the first 5 rows to confirm data has been read
    print(df.head())
except FileNotFoundError:
    print(f"Error: File '{file_name}' not found in directory '{path}'. Please check the file name.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Bengaluru_House_Data.csv
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
#EDA

df.shape
# Out:
# (13320, 9)

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.duplicated().sum()
# Out:
# 529

# %%
for column in df.columns:
    print(df[column].value_counts())
    print("*"*20)
# Out:
# area_type
# Super built-up  Area    6017
# Built-up  Area          1158
# Plot  Area               269
# Carpet  Area              52
# Name: count, dtype: int64
# ********************
# availability
# Ready To Move    5709
# 18-Dec            180
# 18-May            171
# 19-Dec            157
# 18-Apr            148
#                  ...
# 20-Feb              1
# 15-Jun              1
# 20-Mar              1
# 16-Mar              1
# 14-Jul              1
# Name: count, Length: 74, dtype: int64
# ********************
# location
# Whitefield         397
# Sarjapur  Road     310
# Electronic City    236
# Kanakpura Road     216
# Thanisandra        212
#                   ...
# Adarsh Nagar         1
# S R Layout           1
# Sadduguntepalya      1
# BCC Layout           1
# Abshot Layout        1
# Name: count, Length: 634, dtype: int64
# ********************
# size
# 2 BHK        3411
# 3 BHK        3012
# 1 BHK         353
# 4 BHK         347
# 4 Bedroom     193
# 3 Bedroom     120
# 5 Bedroom      16
# 2 Bedroom      16
# 1 RK           10
# 5 BHK           9
# 6 BHK           3
# 6 Bedroom       3
# 11 BHK          1
# 9 BHK           1
# 7 BHK           1
# Name: count, dtype: int64
# ********************
# society
# GrrvaGr    80
# PrarePa    71
# Sryalan    59
# Prtates    58
# GMown E    56
#            ..
# SLnorMa     1
# Heatee      1
# Nihtsur     1
# TGjraVa     1
# RSntsAp     1
# Name: count, Length: 2592, dtype: int64
# ********************
# total_sqft
# 1200           172
# 1100           106
# 1000            78
# 1500            74
# 1300            71
#               ...
# 2383             1
# 1103             1
# 1145 - 1340      1
# 3080             1
# 4689             1
# Name: count, Length: 1682, dtype: int64
# ********************
# bath
# 2.0    4283
# 3.0    2063
# 4.0     458
# 1.0     428
# 5.0     184
# 6.0      73
# 7.0       4
# 9.0       3
# Name: count, dtype: int64
# ********************
# balcony
# 2.0    3114
# 1.0    2975
# 3.0    1005
# 0.0     402
# Name: count, dtype: int64
# ********************
# price
# 75.00     182
# 65.00     171
# 55.00     157
# 60.00     154
# 45.00     148
#          ...
# 34.98       1
# 54.11       1
# 67.90       1
# 62.30       1
# 488.00      1
# Name: count, Length: 1518, dtype: int64
# ********************

# %%
df.drop(columns=['area_type','availability','society','balcony'], inplace=True)

# %%
df.columns
# Out:
# Index(['location', 'size', 'total_sqft', 'bath', 'price'], dtype='object')

# %%
df.describe()
# Out:
#               bath        price
# count  7496.000000  7496.000000
# mean      2.458378    96.857122
# std       0.881128   105.382490
# min       1.000000     8.000000
# 25%       2.000000    49.500000
# 50%       2.000000    69.755000
# 75%       3.000000   105.000000
# max       9.000000  2700.000000

# %%
df['size'].value_counts(
)
# Out:
# size
# 2 BHK        3411
# 3 BHK        3012
# 1 BHK         353
# 4 BHK         347
# 4 Bedroom     193
# 3 Bedroom     120
# 5 Bedroom      16
# 2 Bedroom      16
# 1 RK           10
# 5 BHK           9
# 6 BHK           3
# 6 Bedroom       3
# 11 BHK          1
# 9 BHK           1
# 7 BHK           1
# Name: count, dtype: int64

# %%
df['size'] = df['size'].fillna('2 BHK')

# %%
df['bath'] = df['bath'].fillna(df['bath'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7496 entries, 0 to 13318
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7496 non-null   object
#  1   size        7496 non-null   object
#  2   total_sqft  7496 non-null   object
#  3   bath        7496 non-null   float64
#  4   price       7496 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 351.4+ KB

# %%
df['bhk'] = df['size'].str.split().str.get(0).astype(int)

# %%
df[df.bhk > 10]
# Out:
#          location    size total_sqft  bath  price  bhk
# 459  1 Giri Nagar  11 BHK       5000   9.0  360.0   11

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1521', ..., '1919', '2111', '4689'], dtype=object)

# %%
def convertRange(x):

  temp = x.split('-')
  if len(temp) == 2:
    return (float(temp[0]) + float(temp[1]))/2
  try:
    return float(x)
  except:
    return None

# %%
df['total_sqft'] = df['total_sqft'].apply(convertRange)

# %%
df.head()
# Out:
#                     location       size  total_sqft  bath   price  bhk
# 0   Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1           Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 3         Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 5                 Whitefield      2 BHK      1170.0   2.0   38.00    2
# 11                Whitefield  4 Bedroom      2785.0   5.0  295.00    4

# %% [markdown]
# ## Price Per Square Feet

# %%
df['price_per_sqft'] = df['price'] * 10000/df['total_sqft']

# %%
df['price_per_sqft']
# Out:
# 0         369.981061
# 1         461.538462
# 3         624.589086
# 5         324.786325
# 11       1059.245961
#             ...
# 13313     423.791822
# 13314     653.061224
# 13315     668.983493
# 13317     525.854514
# 13318    1040.733632
# Name: price_per_sqft, Length: 7496, dtype: float64

# %%
df['location'].value_counts()
# Out:
# location
# Whitefield         397
# Sarjapur  Road     310
# Electronic City    236
# Kanakpura Road     216
# Thanisandra        212
#                   ...
# Adarsh Nagar         1
# S R Layout           1
# Sadduguntepalya      1
# BCC Layout           1
# Abshot Layout        1
# Name: count, Length: 634, dtype: int64

# %%
df['location'] = df['location'].apply(lambda x: x.strip())
location_count = df['location'].value_counts()

# %%
location_count
# Out:
# location
# Whitefield         398
# Sarjapur  Road     310
# Electronic City    238
# Kanakpura Road     216
# Thanisandra        215
#                   ...
# HAL 2nd Stage        1
# Adarsh Nagar         1
# S R Layout           1
# Sadduguntepalya      1
# Abshot Layout        1
# Name: count, Length: 626, dtype: int64

# %%
location_count_less_10 = location_count[location_count <= 10]
location_count_less_10
# Out:
# location
# Jalahalli East     10
# Mallasandra        10
# Arekere            10
# Amruthahalli       10
# Rayasandra         10
#                    ..
# HAL 2nd Stage       1
# Adarsh Nagar        1
# S R Layout          1
# Sadduguntepalya     1
# Abshot Layout       1
# Name: count, Length: 483, dtype: int64

# %%
df['location'] = df['location'].apply(lambda x: 'other' if x in location_count_less_10 else x)
df['location'].value_counts()
# Out:
# location
# other                 1443
# Whitefield             398
# Sarjapur  Road         310
# Electronic City        238
# Kanakpura Road         216
#                       ...
# Neeladri Nagar          11
# Billekahalli            11
# Bharathi Nagar          11
# Pattandur Agrahara      11
# AECS Layout             11
# Name: count, Length: 144, dtype: int64

# %% [markdown]
# **Outlier Detection and Removal**

# %%
df.describe()
# Out:
#          total_sqft         bath        price          bhk  price_per_sqft
# count   7481.000000  7496.000000  7496.000000  7496.000000     7481.000000
# mean    1507.516043     2.458378    96.857122     2.529482      599.205823
# std      935.083274     0.881128   105.382490     0.733228      916.084028
# min       11.000000     1.000000     8.000000     1.000000       37.142857
# 25%     1115.000000     2.000000    49.500000     2.000000      427.913101
# 50%     1310.000000     2.000000    69.755000     2.000000      531.914894
# 75%     1656.000000     3.000000   105.000000     3.000000      669.662921
# max    36000.000000     9.000000  2700.000000    11.000000    67272.727273

# %%
(df['total_sqft']/df['bhk']).describe()
# Out:
# count     7481.000000
# mean       588.424430
# std        224.966082
# min          3.666667
# 25%        500.000000
# 50%        567.333333
# 75%        632.500000
# max      11666.666667
# dtype: float64

# %%
df = df[((df['total_sqft']/df['bhk']) >= 300)]
df.describe()
# Out:
#          total_sqft         bath        price          bhk  price_per_sqft
# count   7439.000000  7439.000000  7439.000000  7439.000000     7439.000000
# mean    1512.042279     2.458395    96.958214     2.526818      585.102019
# std      935.456470     0.875626   105.545476     0.727850      270.546570
# min      350.000000     1.000000    10.000000     1.000000       37.142857
# 25%     1120.000000     2.000000    49.935000     2.000000      428.339768
# 50%     1312.000000     2.000000    69.840000     2.000000      531.928480
# 75%     1660.000000     3.000000   105.000000     3.000000      669.388163
# max    36000.000000     9.000000  2700.000000    11.000000     7653.061224

# %%
df.shape
# Out:
# (7439, 7)

# %%
df.price_per_sqft.describe()
# Out:
# count    7439.000000
# mean      585.102019
# std       270.546570
# min        37.142857
# 25%       428.339768
# 50%       531.928480
# 75%       669.388163
# max      7653.061224
# Name: price_per_sqft, dtype: float64

# %%
def remove_outliers_sqft(df):
  df_output = pd.DataFrame()
  for key, subdf in df.groupby('location'):
    m = np.mean(subdf.price_per_sqft)

    st = np.std(subdf.price_per_sqft)
    gen_df = subdf[(subdf.price_per_sqft > (m-st)) & (subdf.price_per_sqft  <= (m+st))]
    df_output = pd.concat([df_output, gen_df],ignore_index= True)
  return df_output
df = remove_outliers_sqft(df)
df.describe()
# Out:
#          total_sqft         bath        price          bhk  price_per_sqft
# count   5862.000000  5862.000000  5862.000000  5862.000000     5862.000000
# mean    1439.280076     2.398499    82.299561     2.484135      544.622754
# std      629.946686     0.815009    56.668313     0.699041      163.809432
# min      350.000000     1.000000    10.000000     1.000000      209.090909
# 25%     1113.000000     2.000000    49.895000     2.000000      432.574673
# 50%     1300.000000     2.000000    68.000000     2.000000      523.820760
# 75%     1614.000000     3.000000    95.000000     3.000000      634.417014
# max    14000.000000     9.000000  1000.000000    11.000000     1574.833919

# %%
def bhk_outlier_remover(df):
  exclude_indices = np.array([])
  for location, location_df in df.groupby('location'):
    bhk_stats = {}
    for bhk, bhk_df in location_df.groupby('bhk'):
      bhk_stats[bhk] = {
          'mean': np.mean(bhk_df.price_per_sqft),
          'std' : np.std(bhk_df.price_per_sqft),
          'count': bhk_df.shape[0]

      }
#   print(location,bhk_stats)
    for bhk, bhk_df in location_df.groupby('bhk'):
      stats = bhk_stats.get(bhk-1)
      if stats  and stats ['count'] > 5:
        exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft < (stats['mean'])].index.values)
    return df.drop(exclude_indices, axis='index')

# %%
df = bhk_outlier_remover(df)

# %%
df.shape
# Out:
# (5862, 7)

# %%
df
# Out:
#                 location   size  total_sqft  bath   price  bhk  price_per_sqft
# 0     1st Phase JP Nagar  4 BHK      2825.0   4.0  250.00    4      884.955752
# 1     1st Phase JP Nagar  3 BHK      1875.0   3.0  167.00    3      890.666667
# 2     1st Phase JP Nagar  2 BHK      1394.0   2.0  100.00    2      717.360115
# 3     1st Phase JP Nagar  2 BHK      1077.0   2.0   93.00    2      863.509749
# 4     1st Phase JP Nagar  3 BHK      1590.0   3.0  131.00    3      823.899371
# ...                  ...    ...         ...   ...     ...  ...             ...
# 5857               other  2 BHK      1000.0   2.0   49.50    2      495.000000
# 5858               other  2 BHK      1256.0   2.0   65.00    2      517.515924
# 5859               other  2 BHK      1353.0   2.0  110.00    2      813.008130
# 5860               other  3 BHK      1440.0   2.0   63.93    3      443.958333
# 5861               other  4 BHK      2200.0   3.0   80.00    4      363.636364
#
# [5862 rows x 7 columns]

# %%
df.drop(columns=['size','price_per_sqft'],inplace=True)

# %%
df.head()
# Out:
#              location  total_sqft  bath  price  bhk
# 0  1st Phase JP Nagar      2825.0   4.0  250.0    4
# 1  1st Phase JP Nagar      1875.0   3.0  167.0    3
# 2  1st Phase JP Nagar      1394.0   2.0  100.0    2
# 3  1st Phase JP Nagar      1077.0   2.0   93.0    2
# 4  1st Phase JP Nagar      1590.0   3.0  131.0    3

# %%
df.to_csv("Cleaned_data.csv")

# %%
X = df.drop(columns=['price'])
y = df['price']

# %% [markdown]
# **Building Model**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (4689, 4)
# (1173, 4)

# %%
# applying linear regression


column_trans = make_column_transformer((OneHotEncoder(sparse_output=False), ['location']),remainder='passthrough')

# %%
scaler = StandardScaler()

model = LinearRegression()
pipe = make_pipeline(column_trans, scaler, model)
pipe.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py:1651: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred_lr = pipe.predict(X_test)

r2_score(y_test, y_pred_lr)
# Out:
# 0.8820801572316153

# %%
lasso = Lasso()
pipe = make_pipeline(column_trans, scaler, lasso)
pipe.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py:1651: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso = pipe.predict(X_test)

r2_score(y_test, y_pred_lasso)
# Out:
# 0.8560850808580185

# %%
ridge = Ridge()
pipe = make_pipeline(column_trans, scaler, ridge)
pipe.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py:1651: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge = pipe.predict(X_test)

# %%
r2_score(y_test, y_pred_ridge)
# Out:
# 0.8820810590736682

# %%
import pickle

# %%
pickle.dump(pipe, open('ridge.pkl','wb'))
